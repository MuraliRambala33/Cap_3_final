# %% [markdown]
# importing libraries

# %% [markdown]
# **The traffic sign classification**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import cv2
import os

# %%
df_train=pd.read_csv('../input/gtsrb-german-traffic-sign/Train.csv')

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
df_train['Class_name']=df_train['ClassId'].map(classes)

# %%
plt.rcParams["figure.figsize"] = (20,8)
dcounts = df_train.Class_name.value_counts(normalize=True)
dcounts_df = pd.DataFrame({'label': dcounts.index.tolist(), 'pct_of_images': dcounts})
dcounts_df.reset_index(drop=True, inplace=True)
dcounts_df[0:42].plot.bar(x='label', y='pct_of_images')

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.layers import Conv2D, MaxPool2D, Dropout, Dense, Flatten
from keras.models import Sequential, load_model

# %% [markdown]
# Image Processing

# %%
data=[]
labels=[]
classes=43
# cur_dir=os.getcwd()

for i in range(classes):
    path = os.path.join('../input/gtsrb-german-traffic-sign/Train',str(i))
    images = os.listdir(path)
    
    for a in images:
        try:
            image = Image.open(path + '//'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
            
        except:
            print("Error loading image")

# %%
# converting list to numpy arrays
    
data=np.array(data)
labels=np.array(labels)

# %%
print('data_shape {}, labels_shape  {}' .format(data.shape,labels.shape))
# Out:
# data_shape (39209, 30, 30, 3), labels_shape  (39209,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data,labels,test_size=0.2,random_state=42)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (31367, 30, 30, 3) (7842, 30, 30, 3)

# %%
y_train=to_categorical(y_train,43)
y_test=to_categorical(y_test,43)

# %%
X_train.shape[1:]

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

# %% [markdown]
# Model_1

# %%
import keras

# %%
# es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
monitor=keras.callbacks.EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=5,
                              verbose=0, mode='auto')

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# epochs = 10
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test),callbacks=[monitor])
# Out:
# Epoch 1/100
# 981/981 [==============================] - 4s 4ms/step - loss: 2.0116 - accuracy: 0.4825 - val_loss: 0.5196 - val_accuracy: 0.8710
# Epoch 2/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.6351 - accuracy: 0.8150 - val_loss: 0.1710 - val_accuracy: 0.9565
# Epoch 3/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.3878 - accuracy: 0.8876 - val_loss: 0.0988 - val_accuracy: 0.9713
# Epoch 4/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.3213 - accuracy: 0.9114 - val_loss: 0.0960 - val_accuracy: 0.9730
# Epoch 5/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2701 - accuracy: 0.9247 - val_loss: 0.0717 - val_accuracy: 0.9811
# Epoch 6/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2704 - accuracy: 0.9257 - val_loss: 0.1019 - val_accuracy: 0.9733
# Epoch 7/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2715 - accuracy: 0.9272 - val_loss: 0.0682 - val_accuracy: 0.9792
# Epoch 8/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.2543 - accuracy: 0.9310 - val_loss: 0.0594 - val_accuracy: 0.9820
# Epoch 9/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2272 - accuracy: 0.9386 - val_loss: 0.0782 - val_accuracy: 0.9783
# Epoch 10/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2310 - accuracy: 0.9377 - val_loss: 0.0810 - val_accuracy: 0.9755
# Epoch 11/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2269 - accuracy: 0.9391 - val_loss: 0.0555 - val_accuracy: 0.9856
# Epoch 12/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2241 - accuracy: 0.9419 - val_loss: 0.0495 - val_accuracy: 0.9875
# Epoch 13/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2004 - accuracy: 0.9466 - val_loss: 0.0403 - val_accuracy: 0.9893
# Epoch 14/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2050 - accuracy: 0.9473 - val_loss: 0.0759 - val_accuracy: 0.9779
# Epoch 15/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2153 - accuracy: 0.9446 - val_loss: 0.0455 - val_accuracy: 0.9883
# Epoch 16/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.2139 - accuracy: 0.9470 - val_loss: 0.0463 - val_accuracy: 0.9870
# Epoch 17/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.2132 - accuracy: 0.9481 - val_loss: 0.0531 - val_accuracy: 0.9844
# Epoch 18/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.2078 - accuracy: 0.9471 - val_loss: 0.0656 - val_accuracy: 0.9825

# %%
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# Model_2 with RMSrop

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.RMSprop(lr=0.0001), metrics=['accuracy'])

# %%
# epochs = 10
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_test, y_test),callbacks=[monitor])
# Out:
# Epoch 1/100
# 981/981 [==============================] - 5s 5ms/step - loss: 3.5891 - accuracy: 0.2408 - val_loss: 2.0639 - val_accuracy: 0.5683
# Epoch 2/100
# 981/981 [==============================] - 4s 5ms/step - loss: 1.7357 - accuracy: 0.5491 - val_loss: 0.9127 - val_accuracy: 0.8179
# Epoch 3/100
# 981/981 [==============================] - 5s 5ms/step - loss: 1.1114 - accuracy: 0.6981 - val_loss: 0.5068 - val_accuracy: 0.8982
# Epoch 4/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.7733 - accuracy: 0.7897 - val_loss: 0.3093 - val_accuracy: 0.9440
# Epoch 5/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.5814 - accuracy: 0.8396 - val_loss: 0.2465 - val_accuracy: 0.9478
# Epoch 6/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.4615 - accuracy: 0.8726 - val_loss: 0.1637 - val_accuracy: 0.9649
# Epoch 7/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.3879 - accuracy: 0.8925 - val_loss: 0.1264 - val_accuracy: 0.9745
# Epoch 8/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.3283 - accuracy: 0.9098 - val_loss: 0.0964 - val_accuracy: 0.9823
# Epoch 9/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.2768 - accuracy: 0.9255 - val_loss: 0.0975 - val_accuracy: 0.9814
# Epoch 10/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.2434 - accuracy: 0.9336 - val_loss: 0.0764 - val_accuracy: 0.9847
# Epoch 11/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.2221 - accuracy: 0.9393 - val_loss: 0.0644 - val_accuracy: 0.9862
# Epoch 12/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1985 - accuracy: 0.9453 - val_loss: 0.0672 - val_accuracy: 0.9851
# Epoch 13/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.1811 - accuracy: 0.9522 - val_loss: 0.0563 - val_accuracy: 0.9885
# Epoch 14/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1637 - accuracy: 0.9549 - val_loss: 0.0418 - val_accuracy: 0.9897
# Epoch 15/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1522 - accuracy: 0.9584 - val_loss: 0.0390 - val_accuracy: 0.9911
# Epoch 16/100
# 981/981 [==============================] - 6s 6ms/step - loss: 0.1376 - accuracy: 0.9630 - val_loss: 0.0370 - val_accuracy: 0.9912
# Epoch 17/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1361 - accuracy: 0.9644 - val_loss: 0.0380 - val_accuracy: 0.9908
# Epoch 18/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.1262 - accuracy: 0.9670 - val_loss: 0.0302 - val_accuracy: 0.9927
# Epoch 19/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1177 - accuracy: 0.9685 - val_loss: 0.0330 - val_accuracy: 0.9923
# Epoch 20/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1104 - accuracy: 0.9710 - val_loss: 0.0316 - val_accuracy: 0.9926
# Epoch 21/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1115 - accuracy: 0.9718 - val_loss: 0.0297 - val_accuracy: 0.9935
# Epoch 22/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1022 - accuracy: 0.9732 - val_loss: 0.0295 - val_accuracy: 0.9932
# Epoch 23/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1008 - accuracy: 0.9748 - val_loss: 0.0292 - val_accuracy: 0.9927
# Epoch 24/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0944 - accuracy: 0.9765 - val_loss: 0.0360 - val_accuracy: 0.9925
# Epoch 25/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.1009 - accuracy: 0.9746 - val_loss: 0.0268 - val_accuracy: 0.9938
# Epoch 26/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0913 - accuracy: 0.9781 - val_loss: 0.0268 - val_accuracy: 0.9940
# Epoch 27/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0867 - accuracy: 0.9785 - val_loss: 0.0216 - val_accuracy: 0.9944
# Epoch 28/100
# 981/981 [==============================] - 6s 6ms/step - loss: 0.0854 - accuracy: 0.9788 - val_loss: 0.0269 - val_accuracy: 0.9930
# Epoch 29/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0870 - accuracy: 0.9785 - val_loss: 0.0271 - val_accuracy: 0.9938
# Epoch 30/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0793 - accuracy: 0.9810 - val_loss: 0.0271 - val_accuracy: 0.9949
# Epoch 31/100
# 981/981 [==============================] - 4s 4ms/step - loss: 0.0750 - accuracy: 0.9814 - val_loss: 0.0235 - val_accuracy: 0.9954
# Epoch 32/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0790 - accuracy: 0.9818 - val_loss: 0.0211 - val_accuracy: 0.9952
# Epoch 33/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0757 - accuracy: 0.9818 - val_loss: 0.0237 - val_accuracy: 0.9952
# Epoch 34/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0792 - accuracy: 0.9805 - val_loss: 0.0193 - val_accuracy: 0.9960
# Epoch 35/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0789 - accuracy: 0.9819 - val_loss: 0.0264 - val_accuracy: 0.9941
# Epoch 36/100
# 981/981 [==============================] - 4s 5ms/step - loss: 0.0768 - accuracy: 0.9817 - val_loss: 0.0194 - val_accuracy: 0.9954
# Epoch 37/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0721 - accuracy: 0.9832 - val_loss: 0.0260 - val_accuracy: 0.9943
# Epoch 38/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0702 - accuracy: 0.9845 - val_loss: 0.0210 - val_accuracy: 0.9959
# Epoch 39/100
# 981/981 [==============================] - 5s 5ms/step - loss: 0.0654 - accuracy: 0.9846 - val_loss: 0.0239 - val_accuracy: 0.9954

# %%
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
def test_on_img(img):
    data=[]
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))
    X_test=np.array(data)
    Y_pred = model.predict_classes(X_test)
    return image,Y_pred

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
plot,prediction = test_on_img('../input/gtsrb-german-traffic-sign/Test/00011.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# Predicted traffic sign is:  Speed limit (100km/h)

# %%
from sklearn.metrics import accuracy_score

pred=model.predict(X_test)
prected_class=np.argmax(pred,axis=1)
expected_class=np.argmax(y_test,axis=1)

correct=accuracy_score(expected_class,prected_class)

print('Accuracy{}' .format(correct))
# Out:
# Accuracy0.9954093343534812
